# %%
import numpy as np
import matplotlib.pyplot as plt


fig = plt.figure()
theta = np.linspace(0, 6*np.pi, 200)
r = np.log(theta/np.pi)
x, y, z = r*np.cos(theta), r*np.sin(theta), theta
ax = fig.gca(projection='3d')
ax.plot(x, y, z)
# Out:
# /tmp/wsuser/ipykernel_164/2084584394.py:7: RuntimeWarning: divide by zero encountered in log
#   r = np.log(theta/np.pi)
# /tmp/wsuser/ipykernel_164/2084584394.py:8: RuntimeWarning: invalid value encountered in multiply
#   x, y, z = r*np.cos(theta), r*np.sin(theta), theta
# /tmp/wsuser/ipykernel_164/2084584394.py:9: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
