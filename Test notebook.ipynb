# %%
import numpy as np
import matplotlib.pyplot as plt


fig = plt.figure()
theta = np.linspace(0, 6*np.pi, 200)
r = np.log(1 + theta/np.pi)
x, y, z = r*np.cos(theta), r*np.sin(theta), theta
ax = plt.axes(projection='3d')
ax.plot(x, y, z)
